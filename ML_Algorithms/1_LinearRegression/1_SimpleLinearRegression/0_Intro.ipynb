# %% [markdown]
# # Linear Regression
# [source](https://www.youtube.com/watch?v=UZPfbG0jNec&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH&index=50)
# <br><br>
# ![ytss](assets/LR.png)
# <br><br>
# Linear Regression is a Supervised Regression Machine Learning Algorithm. There are 4 types of Linear Rgression
# 1. **Simple LR**
#    There is only input column and only 1 output column
# 2. **Multiple LR**
#    There are multiple input columns
# 3. **Polynomial LR**:
#    _(no details yet)_ used when the data isn't linear.
# 4. **Regularization**:
#    _(No details yet)_
