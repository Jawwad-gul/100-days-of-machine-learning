# %% [markdown]
# # **Encoding Numeric Features**
# _Group values together and name mutliple numeric vales as a single name_
# <br><br>
# * **Binning/Discretization**
# * **Binarization**
# ![ytss](assets/types.png)
